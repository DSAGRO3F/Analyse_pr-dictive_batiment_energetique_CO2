# %% [markdown]
# <h1>Sommaire<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Contexte-et-objectifs-de-l'étude." data-toc-modified-id="Contexte-et-objectifs-de-l'étude.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Contexte et objectifs de l'étude.</a></span><ul class="toc-item"><li><span><a href="#Bâtiment-et-énergie:" data-toc-modified-id="Bâtiment-et-énergie:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Bâtiment et énergie:</a></span></li><li><span><a href="#Objectifs:" data-toc-modified-id="Objectifs:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Objectifs:</a></span></li></ul></li><li><span><a href="#Import-packages" data-toc-modified-id="Import-packages-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import packages</a></span></li><li><span><a href="#Phase-exploratoire." data-toc-modified-id="Phase-exploratoire.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Phase exploratoire.</a></span><ul class="toc-item"><li><span><a href="#Chargement-data" data-toc-modified-id="Chargement-data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Chargement data</a></span></li><li><span><a href="#Format-dataset,-données-manquantes" data-toc-modified-id="Format-dataset,-données-manquantes-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Format dataset, données manquantes</a></span><ul class="toc-item"><li><span><a href="#Histograme-target" data-toc-modified-id="Histograme-target-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Histograme target</a></span></li><li><span><a href="#Dépendance-des-variables-numériques." data-toc-modified-id="Dépendance-des-variables-numériques.-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Dépendance des variables numériques.</a></span></li><li><span><a href="#Question-de-la-qualité-des-données-pour-le-dataset-&quot;numerical&quot;." data-toc-modified-id="Question-de-la-qualité-des-données-pour-le-dataset-&quot;numerical&quot;.-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Question de la qualité des données pour le dataset "numerical".</a></span><ul class="toc-item"><li><span><a href="#Pour-les-colonnes-numériques-pour-lesquelles-on-a-des-valeurs-manquantes,-quelle-est-la-distribution-des-données-?" data-toc-modified-id="Pour-les-colonnes-numériques-pour-lesquelles-on-a-des-valeurs-manquantes,-quelle-est-la-distribution-des-données-?-3.2.3.1"><span class="toc-item-num">3.2.3.1&nbsp;&nbsp;</span>Pour les colonnes numériques pour lesquelles on a des valeurs manquantes, quelle est la distribution des données ?</a></span></li></ul></li><li><span><a href="#Question-de-la-dimension-de-la-matrice." data-toc-modified-id="Question-de-la-dimension-de-la-matrice.-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Question de la dimension de la matrice.</a></span></li></ul></li></ul></li><li><span><a href="#Phase-Preprocessing." data-toc-modified-id="Phase-Preprocessing.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Phase Preprocessing.</a></span><ul class="toc-item"><li><span><a href="#Sélection-des-features:-Méthode-VarianceThreshold" data-toc-modified-id="Sélection-des-features:-Méthode-VarianceThreshold-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Sélection des features: Méthode VarianceThreshold</a></span><ul class="toc-item"><li><span><a href="#Quelles-sont-les-data-qui-peuvent-être-utiles-à-la-caractérisation-de-la-target-?" data-toc-modified-id="Quelles-sont-les-data-qui-peuvent-être-utiles-à-la-caractérisation-de-la-target-?-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Quelles sont les data qui peuvent être utiles à la caractérisation de la target ?</a></span></li></ul></li><li><span><a href="#Phase-modelling:-selection-features-avec-KBest,-SVR" data-toc-modified-id="Phase-modelling:-selection-features-avec-KBest,-SVR-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Phase modelling: selection features avec KBest, SVR</a></span><ul class="toc-item"><li><span><a href="#Création-&quot;numerical_features&quot;-et-&quot;categorical_features&quot;" data-toc-modified-id="Création-&quot;numerical_features&quot;-et-&quot;categorical_features&quot;-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Création "numerical_features" et "categorical_features"</a></span><ul class="toc-item"><li><span><a href="#Définition-des-subsets-X-et-y." data-toc-modified-id="Définition-des-subsets-X-et-y.-4.2.1.1"><span class="toc-item-num">4.2.1.1&nbsp;&nbsp;</span>Définition des subsets X et y.</a></span></li></ul></li><li><span><a href="#Définition-des-features" data-toc-modified-id="Définition-des-features-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Définition des features</a></span></li><li><span><a href="#Construction-des-pipelines-&quot;Num&quot;-et-&quot;Cat&quot;" data-toc-modified-id="Construction-des-pipelines-&quot;Num&quot;-et-&quot;Cat&quot;-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Construction des pipelines "Num" et "Cat"</a></span></li><li><span><a href="#Définition-des-transformations" data-toc-modified-id="Définition-des-transformations-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Définition des transformations</a></span></li><li><span><a href="#Transformations-sur-y" data-toc-modified-id="Transformations-sur-y-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Transformations sur y</a></span></li><li><span><a href="#Split-dataset" data-toc-modified-id="Split-dataset-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Split dataset</a></span></li><li><span><a href="#Construction-de-la-pipeline-transformations-+-selection-features-+-estimateur" data-toc-modified-id="Construction-de-la-pipeline-transformations-+-selection-features-+-estimateur-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Construction de la pipeline transformations + selection features + estimateur</a></span></li><li><span><a href="#Score" data-toc-modified-id="Score-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>Score</a></span></li></ul></li></ul></li><li><span><a href="#Phase-Modelling:-Regression-polynomiale" data-toc-modified-id="Phase-Modelling:-Regression-polynomiale-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Phase Modelling: Regression polynomiale</a></span><ul class="toc-item"><li><span><a href="#Création-nouveau-preprocessor" data-toc-modified-id="Création-nouveau-preprocessor-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Création nouveau preprocessor</a></span></li><li><span><a href="#Optimisation-hyper-paramètre-degré-du-polynome" data-toc-modified-id="Optimisation-hyper-paramètre-degré-du-polynome-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Optimisation hyper paramètre degré du polynome</a></span></li><li><span><a href="#Output-phase-optimisation" data-toc-modified-id="Output-phase-optimisation-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Output phase optimisation</a></span></li><li><span><a href="#Performance-modèle-régression-polynomiale" data-toc-modified-id="Performance-modèle-régression-polynomiale-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Performance modèle régression polynomiale</a></span></li></ul></li><li><span><a href="#Phase-Modelling:-Random-Forest" data-toc-modified-id="Phase-Modelling:-Random-Forest-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Phase Modelling: Random Forest</a></span><ul class="toc-item"><li><span><a href="#Instantiation-du-modèle,-entrainement" data-toc-modified-id="Instantiation-du-modèle,-entrainement-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Instantiation du modèle, entrainement</a></span><ul class="toc-item"><li><span><a href="#Définition-modèle-et-preprocessing" data-toc-modified-id="Définition-modèle-et-preprocessing-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Définition modèle et preprocessing</a></span></li></ul></li><li><span><a href="#Entrainement" data-toc-modified-id="Entrainement-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Entrainement</a></span></li><li><span><a href="#Score" data-toc-modified-id="Score-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Score</a></span></li><li><span><a href="#Classement-des-variables-(Feature-importance)" data-toc-modified-id="Classement-des-variables-(Feature-importance)-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Classement des variables (Feature importance)</a></span></li></ul></li><li><span><a href="#Phase-Modelling:-Adaboost" data-toc-modified-id="Phase-Modelling:-Adaboost-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Phase Modelling: Adaboost</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Définition-modèle-et-preprocessing" data-toc-modified-id="Définition-modèle-et-preprocessing-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Définition modèle et preprocessing</a></span></li></ul></li><li><span><a href="#Entrainement" data-toc-modified-id="Entrainement-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Entrainement</a></span></li><li><span><a href="#Score." data-toc-modified-id="Score.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Score.</a></span></li></ul></li><li><span><a href="#Première-conclusion" data-toc-modified-id="Première-conclusion-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Première conclusion</a></span></li><li><span><a href="#Modélisation-pour-le-non-résidentiel" data-toc-modified-id="Modélisation-pour-le-non-résidentiel-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Modélisation pour le non résidentiel</a></span><ul class="toc-item"><li><span><a href="#Réduction-dataset,-exclusion-des-bâtiments-destinés-à-l'habitation." data-toc-modified-id="Réduction-dataset,-exclusion-des-bâtiments-destinés-à-l'habitation.-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Réduction dataset, exclusion des bâtiments destinés à l'habitation.</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#Split-dataset" data-toc-modified-id="Split-dataset-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Split dataset</a></span></li><li><span><a href="#Application-modèle,-Random-Forest" data-toc-modified-id="Application-modèle,-Random-Forest-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Application modèle, Random Forest</a></span></li><li><span><a href="#Score" data-toc-modified-id="Score-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Score</a></span></li></ul></li><li><span><a href="#Importance-variable-EnergyStarScore,-&quot;SiteEUI(kBtu/sf)&quot;,-non-résidentiel." data-toc-modified-id="Importance-variable-EnergyStarScore,-&quot;SiteEUI(kBtu/sf)&quot;,-non-résidentiel.-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Importance variable EnergyStarScore, "SiteEUI(kBtu/sf)", non résidentiel.</a></span><ul class="toc-item"><li><span><a href="#Analyse-de-l'influence." data-toc-modified-id="Analyse-de-l'influence.-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Analyse de l'influence.</a></span></li><li><span><a href="#Conclusion." data-toc-modified-id="Conclusion.-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Conclusion.</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Contexte et objectifs de l'étude.
# ### Bâtiment et énergie:
# - Le secteur du bâtiment représente 44 % de l’énergie consommée en France, loin devant le secteur des transports (31,3%). Chaque année, le secteur du bâtiment émet plus de 123 millions de tonnes de C02, ce qui en fait l’un des domaines clé dans la lutte contre le réchauffement climatique et la transition énergétique. Pour rendre le bâtiment plus économe en énergie, il faut rénover massivement l’existant et développer des normes plus strictes en termes de consommation d’énergie pour les bâtiments neufs. C’est l’objet de la politique de l’énergie dans les bâtiments. (https://www.ecologie.gouv.fr/energie-dans-batiments). Dans ce contexte de réduction drastique de la consommation énergétique des bâtiments et de la réduction tout aussi sévère des émissions de CO2, ainsi que du renchérissement du coût de l'énergie la ville a depuis plusieurs années procédé à des relevés de mesures.
# - Celles-ci sont couteuses. A partir de ces relevés, existe t-il des techniques fiables permettant d'estimer la consommation et les niveaux d'émissions pour des bâtiments non destinés à l'habitation et pour lesquels on n'a pas de mesures ?
# - Les relevés fournis concernent des données structurelles des bâtiments (taille et usage des bâtiments, date de construction, situation géographique, ...)
# - Dans cette étude, on s'intéresse également à la mesure "Energy star score" pour la prédiction d'émissions. Mesure d'une approche fastidieuse et l'on cherchera à juger de son intérêt.
#
# ### Objectifs:
# - Réaliser une courte analyse exploratoire.
# - Tester différents modèles de prédiction afin de répondre au mieux à la problématique.

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import validation_curve
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import learning_curve

from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error

from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector

from sklearn.pipeline import make_pipeline

from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

from sklearn.decomposition import PCA

from sklearn.feature_selection import VarianceThreshold, SelectKBest, f_classif, f_regression

from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor

# %% [markdown]
# ## Phase exploratoire.

# %% [markdown]
# ### Chargement data

# %%
path= '/Users/olivierdebeyssac/Open Classrooms/Data_scientist/Projet_4_Anticipez_les_besoins_en_consommation_de_bâtiments/Data/2016_Building_Energy_Benchmarking.csv'
df = pd.read_csv (path, sep=',')

# %%
df.head(3)
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
#
#               PropertyName          Address     City State  ZipCode  \
# 0     Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1          Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2  5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# 1                    0659000220  ...      9.504252e+05         3242851.0
# 2                    0659000475  ...      1.451544e+07        49526664.0
#
#    NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  Comments  \
# 0         12764.52930         1276453.0        False       NaN
# ...

# %%
df.loc[:, 'BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'Multifamily MR (5-9)',
#        'SPS-District K-12', 'Campus', 'Multifamily LR (1-4)',
#        'Multifamily HR (10+)', 'Nonresidential WA'], dtype=object)

# %%
df.loc[:, 'PrimaryPropertyType'].unique()
# Out:
# array(['Hotel', 'Other', 'Mid-Rise Multifamily', 'Mixed Use Property',
#        'K-12 School', 'University', 'Small- and Mid-Sized Office',
#        'Self-Storage Facility', 'Warehouse', 'Large Office',
#        'Senior Care Community', 'Medical Office', 'Retail Store',
#        'Hospital', 'Residence Hall', 'Distribution Center',
#        'Worship Facility', 'Low-Rise Multifamily',
#        'Supermarket / Grocery Store', 'Laboratory',
#        'Refrigerated Warehouse', 'Restaurant', 'High-Rise Multifamily',
#        'Office'], dtype=object)

# %%
df.groupby(['BuildingType', 'PrimaryPropertyType']).count()
# Out:
#                                                   OSEBuildingID  DataYear  \
# BuildingType         PrimaryPropertyType
# Campus               K-12 School                              4         4
#                      Large Office                             1         1
#                      Low-Rise Multifamily                     1         1
#                      Mixed Use Property                       4         4
#                      Other                                    7         7
#                      Restaurant                               1         1
#                      University                               6         6
# Multifamily HR (10+) High-Rise Multifamily                  105       105
#                      Hotel                                    1         1
#                      Other                                    1         1
#                      Senior Care Community                    3         3
# ...

# %%
# Nomenclature des bâtiments à usage non habitation (à partir de variable "BuildingType").
non_residential = ['NonResidential', 'Nonresidential COS','SPS-District K-12', 'Campus','Nonresidential WA']

# %% [markdown]
# ### Format dataset, données manquantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    3376 non-null   int64
#  1   DataYear                         3376 non-null   int64
#  2   BuildingType                     3376 non-null   object
#  3   PrimaryPropertyType              3376 non-null   object
#  4   PropertyName                     3376 non-null   object
#  5   Address                          3376 non-null   object
#  6   City                             3376 non-null   object
#  7   State                            3376 non-null   object
#  8   ZipCode                          3360 non-null   float64
#  9   TaxParcelIdentificationNumber    3376 non-null   object
#  10  CouncilDistrictCode              3376 non-null   int64
#  11  Neighborhood                     3376 non-null   object
# ...

# %% [markdown]
# #### Histograme target

# %%
fig, axes = plt.subplots(1, 1, figsize=(8,5))
data= df
target= df.loc[:,['SiteEUI(kBtu/sf)']]

sns.histplot(x=target.values.ravel(),kde=True, ax=axes)
plt.show()

# %% [markdown]
# #### Dépendance des variables numériques.

# %% [markdown]
# Il y a deux raisons pour exclure certaines variables:
# - Des variables qui ne varient pas
# - Des variables (features) qui sont corellées entre elles et "disent" à peu près la même chose. Elles sont redondantes et n'apportent pas plus d'information au modèle pour caractériser le label "y".
# A partir de ce rationnel, on va exclure les features qui sont concernées.
#
#
#
#
# La variable "y" (target) est fortement corrélée aux variables "SiteEUIWN(KBtu/sf)", "SourceEUI(KBtu/sf)", "SourceEUIWN(KBtu/sf)". Ce sont des variables dépendantes de la variable "y" qu'il faut exclure de l'analyse, le risque étant que le modèle ne sache pas interpréter le lien de dépendance.

# %%
dropped_1 = ['DataYear', 'ZipCode', 'CouncilDistrictCode', 'OSEBuildingID','Comments', 'Outlier', 'DefaultData']

# %%
# Suppression colonnes "Comments" et "Outlier", ..., inutiles dans la suite des analyses.
df_temp = df.drop(dropped_1, axis=1)

# %%
# Numerical dataset
numerical_features = df_temp.loc[:, df_temp.dtypes != 'object']
print(numerical_features.shape)
# Out:
# (3376, 25)

# %%
numerical_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         3376 non-null   float64
#  1   Longitude                        3376 non-null   float64
#  2   YearBuilt                        3376 non-null   int64
#  3   NumberofBuildings                3368 non-null   float64
#  4   NumberofFloors                   3376 non-null   int64
#  5   PropertyGFATotal                 3376 non-null   int64
#  6   PropertyGFAParking               3376 non-null   int64
#  7   PropertyGFABuilding(s)           3376 non-null   int64
#  8   LargestPropertyUseTypeGFA        3356 non-null   float64
#  9   SecondLargestPropertyUseTypeGFA  1679 non-null   float64
#  10  ThirdLargestPropertyUseTypeGFA   596 non-null    float64
#  11  ENERGYSTARScore                  2533 non-null   float64
# ...

# %%
corr_ = numerical_features.corr()
fig, axes = plt.subplots(1,1, figsize=(8,8))

sns.heatmap(corr_, ax= axes)
plt.show()

# %% [markdown]
# Suppression des features numériques fortement corrélées entre elles.

# %%
dropped_2=['PropertyGFATotal','SiteEUIWN(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'SiteEnergyUseWN(kBtu)', 'Electricity(kWh)',
          'NaturalGas(therms)']

# %%
# Suppression des features fortement corrélées entre elles.
numerical_features = numerical_features.loc[:,~numerical_features.columns.isin(dropped_2)]

# %%
numerical_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         3376 non-null   float64
#  1   Longitude                        3376 non-null   float64
#  2   YearBuilt                        3376 non-null   int64
#  3   NumberofBuildings                3368 non-null   float64
#  4   NumberofFloors                   3376 non-null   int64
#  5   PropertyGFAParking               3376 non-null   int64
#  6   PropertyGFABuilding(s)           3376 non-null   int64
#  7   LargestPropertyUseTypeGFA        3356 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  1679 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   596 non-null    float64
#  10  ENERGYSTARScore                  2533 non-null   float64
#  11  SiteEUI(kBtu/sf)                 3369 non-null   float64
# ...

# %% [markdown]
# ###### Visualisation enntre variables explicatives et variable expliquée, y.

# %%
# Visualisation.
l_features = numerical_features.columns

def vis(df,l):
    
    x_features = l_features[0:-1]
    label = 'SiteEUI(kBtu/sf)'
    
    x = df.loc[:,x_features]
    y = df[label]
    
    nb = len(x_features)
    nb_cols = 3
    
    if nb%nb_cols !=0:
        nb_rows = (nb//nb_cols) + 1
    else:
        nb_rows = (nb//nb_cols)
    
        
    fig, axes = plt.subplots(nb_rows, nb_cols, figsize=(8, 15))
    plt.tight_layout(pad=4.0)
    
        
    for j, ax in enumerate(axes.flat):
        diff = (nb_rows * nb_cols) - nb
        col_name = x.columns[j - diff]
        s = x.loc[:, col_name]
        
        sns.scatterplot(x=s,y=y, ax=ax)
        
        ax.set_xlabel(col_name,fontsize=7)
        ax.set_ylabel(label,fontsize=7)
    
        
        # ax.set_xticklabels(s, fontsize=6)
        # ax.set_yticklabels(y, fontsize=6)
        
    plt.show()
            
    return

# %%
vis(numerical_features, l_features)

# %% [markdown]
# Certaines features ont une propension à expliquer le label. C'est le cas de "PropertyGFAParking", "SecondLargestPropertyUseTypeGFA", "ThirdLargestPropertyUseTypeGFA", "SourceEUI(kBtu/sf)" par exemple.

# %% [markdown]
# #### Question de la qualité des données pour le dataset "numerical".

# %% [markdown]
# ##### Pour les colonnes numériques pour lesquelles on a des valeurs manquantes, quelle est la distribution des données ?
# - Est ce que les données sont assez concentrées ? Si c'est le cas, on remplacera les valeurs manquantes par la moyenne
# - Si les données ne sont pas concentrées, on remplacera les valeurs par la médiane.
# - Commençons par tracer les boxplots pour chacune des colonnes numériques avec val. manquantes.

# %%
def extract_cols(df):
    l = []
    for i in range(len(df.columns)):
        serie = df.iloc[:, i]
        if serie.dtype == 'int64' or serie.dtype == 'float64':
            if serie.count() < len(df):
                l.append(serie)
    return l

# %%
l = extract_cols(numerical_features)

# %%
l_series = pd.DataFrame(l)
print(l_series.shape)
# Out:
# (13, 3376)

# %%
l_series = l_series.transpose()

# %%
l_series.head()
# Out:
#    NumberofBuildings  LargestPropertyUseTypeGFA  \
# 0                1.0                    88434.0
# 1                1.0                    83880.0
# 2                1.0                   756493.0
# 3                1.0                    61320.0
# 4                1.0                   123445.0
#
#    SecondLargestPropertyUseTypeGFA  ThirdLargestPropertyUseTypeGFA  \
# 0                              NaN                             NaN
# 1                          15064.0                          4622.0
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                          68009.0                             0.0
#
#    ENERGYSTARScore  SiteEUI(kBtu/sf)  SourceEUI(kBtu/sf)  SiteEnergyUse(kBtu)  \
# 0             60.0         81.699997          182.500000            7226362.5
# 1             61.0         94.800003          176.100006            8387933.0
# ...

# %%
def affiche(df):
    print(len(df.columns))
    if len(df.columns)%2 == 0:
        n_rows = int(len(df.columns)/4)
        n_cols = 4
        
    else:
        n_rows = int(len(df.columns)/3)
        n_cols = int(len(df.columns)/n_rows) + 1
        
        #print(n_rows)
        #print(n_cols)
        

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(10,12))
    plt.tight_layout(pad=3.0)
    
    for ligne, ax in enumerate(axes.flatten()):
        sns.boxplot(y=df.iloc[:,ligne-3], ax=ax)
        ax.set_ylabel(df.columns[ligne-3],fontsize=7)
        ax.tick_params(labelsize=6)

    plt.show()
    return

# %%
affiche(l_series)
# Out:
# 13

# %% [markdown]
#     Pour les colonnes numériques ayant des valeurs manquantes on peut remplacer par la valeurs médiane des features

# %%
numerical_features.isna().mean()*100
# Out:
# Latitude                            0.000000
# Longitude                           0.000000
# YearBuilt                           0.000000
# NumberofBuildings                   0.236967
# NumberofFloors                      0.000000
# PropertyGFAParking                  0.000000
# PropertyGFABuilding(s)              0.000000
# LargestPropertyUseTypeGFA           0.592417
# SecondLargestPropertyUseTypeGFA    50.266588
# ThirdLargestPropertyUseTypeGFA     82.345972
# ENERGYSTARScore                    24.970379
# SiteEUI(kBtu/sf)                    0.207346
# SourceEUI(kBtu/sf)                  0.266588
# SiteEnergyUse(kBtu)                 0.148104
# SteamUse(kBtu)                      0.266588
# Electricity(kBtu)                   0.266588
# NaturalGas(kBtu)                    0.266588
# TotalGHGEmissions                   0.266588
# GHGEmissionsIntensity               0.266588
# dtype: float64

# %%
numerical_features = numerical_features.fillna(numerical_features.median())

# %%
numerical_features.isna().any()
# Out:
# Latitude                           False
# Longitude                          False
# YearBuilt                          False
# NumberofBuildings                  False
# NumberofFloors                     False
# PropertyGFAParking                 False
# PropertyGFABuilding(s)             False
# LargestPropertyUseTypeGFA          False
# SecondLargestPropertyUseTypeGFA    False
# ThirdLargestPropertyUseTypeGFA     False
# ENERGYSTARScore                    False
# SiteEUI(kBtu/sf)                   False
# SourceEUI(kBtu/sf)                 False
# SiteEnergyUse(kBtu)                False
# SteamUse(kBtu)                     False
# Electricity(kBtu)                  False
# NaturalGas(kBtu)                   False
# TotalGHGEmissions                  False
# GHGEmissionsIntensity              False
# dtype: bool

# %% [markdown]
# #### Question de la dimension de la matrice.

# %% [markdown]
# Dans les étapes précédentes, on a regardé si les variables indépendantes étaient corrélées entre elles. Certaines variables étaient corrélées, on les a exclues pour ne pas perturber l'analyse. On peut maintenant se demander si il est opportun de réduire la dimension de cette matrice pour simplifier notre analyse.

# %%
# Construction pipeline: remplacement Nan/imputation et centrage data
pipe = make_pipeline(SimpleImputer(missing_values=np.nan, strategy='median'), 
              StandardScaler())

# %%
# Chaine de transformation:
preprocessor_pca = make_column_transformer((pipe, numerical_features.columns), remainder='passthrough')

# %%
# Application PCA(). Détermination du nombre de composantes pour obtenir une variance de 0.85
estimator = PCA(n_components=0.90)

# %%
model_pca = make_pipeline(preprocessor_pca,estimator)

# %%
model_pca.fit_transform(numerical_features)
# Out:
# array([[ 0.54605191, -0.85483302,  0.26328418, ...,  0.67143317,
#          1.08703824,  0.93655603],
#        [ 0.70444158, -0.971564  , -0.6319059 , ...,  0.23517474,
#         -0.26490563,  1.2044892 ],
#        [ 9.11144054,  1.8897386 , -2.3532248 , ...,  5.00484305,
#          2.05231192,  1.83017331],
#        ...,
#        [ 2.43916603, -9.75963047,  1.49631042, ...,  0.15070667,
#         -0.75500146,  1.35246357],
#        [-0.7709656 , -0.17952782,  0.42710303, ..., -0.05959293,
#         -1.86201027,  0.08745701],
#        [-0.64179257, -0.65063417,  0.85364105, ...,  0.01670306,
#         -0.93815877, -0.02056273]])

# %%
# Projection des features sur les composantes principales.
print(estimator.components_)
# Out:
# [[-1.26426092e-02  1.62397231e-02  2.79336814e-02  2.61726481e-01
#    1.31703904e-01  1.20858660e-01  3.46798154e-01  3.51551383e-01
#    2.22443541e-01  1.62793851e-01 -2.74842708e-02  1.46770441e-01
#    1.40143302e-01  3.92316040e-01  2.44442673e-01  3.75325345e-01
#    2.03944036e-01  3.43974658e-01  1.48729019e-01]
#  [ 2.92510547e-02 -2.66393490e-02  7.63269235e-02  2.11222667e-01
#    1.22971782e-01  7.48772342e-02  2.41669706e-01  2.39937148e-01
#    4.50242910e-02 -8.83231363e-02  2.08933281e-01 -5.00241692e-01
#   -4.45567874e-01  1.64753873e-02  6.84658919e-02  8.57261677e-02
#   -2.51068571e-01 -1.11198031e-01 -4.70456145e-01]
#  [ 5.33217949e-03  4.07196618e-02 -2.48976211e-01  3.54395706e-01
#   -3.92852203e-01 -4.26854143e-01  3.74007549e-02  7.00300775e-02
#   -4.49316957e-01 -3.70159561e-01 -8.01022393e-02  5.03713077e-02
#    2.29129564e-02  1.04444173e-01  2.33779461e-01  1.20266315e-01
#   -1.84252311e-01  3.22673843e-02  6.70051566e-02]
# ...

# %%
print(estimator.get_feature_names_out())
# Out:
# ['pca0' 'pca1' 'pca2' 'pca3' 'pca4' 'pca5' 'pca6' 'pca7' 'pca8' 'pca9']

# %%
# Variance conservée après réduction de dimension
print(estimator.explained_variance_)
# Out:
# [6.08271543 2.6720287  1.983352   1.47697498 1.09133929 1.00194533
#  0.92988651 0.82804909 0.80413591 0.59188218]

# %%
cum_var = np.cumsum(estimator.explained_variance_)
print(cum_var)
# Out:
# [ 6.08271543  8.75474414 10.73809614 12.21507112 13.30641041 14.30835574
#  15.23824225 16.06629134 16.87042725 17.46230943]

# %%
# Taux de variance conservée après réduction de dimension
print(estimator.explained_variance_ratio_)
# Out:
# [0.32004809 0.14059143 0.10435603 0.0777125  0.0574219  0.05271834
#  0.0489269  0.04356862 0.04231041 0.03114247]

# %%
cum_var_ratio = np.cumsum(estimator.explained_variance_ratio_)
print(cum_var_ratio)
# Out:
# [0.32004809 0.46063952 0.56499555 0.64270805 0.70012994 0.75284829
#  0.80177519 0.84534381 0.88765422 0.91879668]

# %%
# Taux de variance conservée après réduction de dimension
print(estimator.n_features_in_)
# Out:
# 19

# %%
x= estimator.get_feature_names_out()
y= cum_var_ratio
df_pca = pd.DataFrame({'valeurs':y}, index=x)
print(df_pca)

fig, axes = plt.subplots(1,1, figsize=(6,5))
sns.barplot(x=df_pca.index, y='valeurs', data=df_pca)
plt.title('PCA-Variance cumulée')
sns.lineplot(x=df_pca.index, y='valeurs', data=df_pca, c='red')
plt.show()
# Out:
#        valeurs
# pca0  0.320048
# pca1  0.460640
# pca2  0.564996
# pca3  0.642708
# pca4  0.700130
# pca5  0.752848
# pca6  0.801775
# pca7  0.845344
# pca8  0.887654
# pca9  0.918797

# %% [markdown]
# Pour atteindre 85% de la variance initiale, il faut 8 composantes principales. On ne va pas à ce stade retenir cette méthode (variance pas assez élevée, perte d'information susceptible de perturber notre analyse). On préfère faire une sélection de features en se basant soit sur VarianceThrehold ,soit sur KBest. On étudie ci-après les deux méthodes.

# %% [markdown]
# ## Phase Preprocessing.

# %% [markdown]
# ### Sélection des features: Méthode VarianceThreshold
# - Construction d'une pipeline pour les numerical_features
# - Construction d'une pipeline pour les categorical_features

# %%
# Liste des feature names.
l_feat_names = numerical_features.columns
print(l_feat_names)
# Out:
# Index(['Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseTypeGFA', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SourceEUI(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kBtu)', 'NaturalGas(kBtu)', 'TotalGHGEmissions',
#        'GHGEmissionsIntensity'],
#       dtype='object')

# %% [markdown]
# #### Quelles sont les data qui peuvent être utiles à la caractérisation de la target ?
# - Quelle est la variance des features ? (utile à comprendre les variables qui ne varient pas)
# - Première analyse: Utilisation VarianceThreshold().
# - Quelle valeur de seuil peut on fixer ?
# - Calculons la variance pour chacune des features
# - Calculons la moyenne des variances
# - Fixation du seuil= moyenne des variances
# - Application des transformations sur dataset numerical_features
# - Noms features dans array
# - Récupération des features sélectionnées.

# %%
# calcul variance moyenne des features "numerical_features":
def var_thresh(df):
    
    X = df.drop('SiteEUI(kBtu/sf)', axis=1).values
    X_var_med = np.median(X.var(axis=1))
        
    print("variance médiane: {}".format(X_var_med))
    
    seuil = X_var_med
    
    feature_names = df.drop('SiteEUI(kBtu/sf)', axis=1).columns
    arr_names = np.array(feature_names)
    arr_names = arr_names.reshape(1, -1)
    print(arr_names.shape)

    selector = VarianceThreshold(threshold=seuil)
    
    print(X.shape)
    
    selected = selector.fit_transform(X)
    
    selector.get_support()
#     print(selector.get_support().shape)
#     print(selector.get_support().reshape((1, -1)))
    
    
#     print(arr_labels.shape)
#     print(selector.get_support().shape)
#     print(selected.shape)
#     print(selected.dtype)
#     print(selected)
    
    
    return arr_names[selector.get_support().reshape((1, -1))], arr_names[~selector.get_support().reshape((1, -1))]

# %%
selected, not_selected = var_thresh(numerical_features)[0], var_thresh(numerical_features)[1]
# Out:
# variance médiane: 265396570782.03918
# (1, 18)
# (3376, 18)
# variance médiane: 265396570782.03918
# (1, 18)
# (3376, 18)

# %%
selected.shape, not_selected.shape
# Out:
# ((4,), (14,))

# %%
print("Selected features: {}".format(selected))
print()
print("No selected features: {}".format(not_selected))
# Out:
# Selected features: ['SiteEnergyUse(kBtu)' 'SteamUse(kBtu)' 'Electricity(kBtu)'
#  'NaturalGas(kBtu)']
#
# No selected features: ['Latitude' 'Longitude' 'YearBuilt' 'NumberofBuildings' 'NumberofFloors'
#  'PropertyGFAParking' 'PropertyGFABuilding(s)' 'LargestPropertyUseTypeGFA'
#  'SecondLargestPropertyUseTypeGFA' 'ThirdLargestPropertyUseTypeGFA'
#  'ENERGYSTARScore' 'SourceEUI(kBtu/sf)' 'TotalGHGEmissions'
#  'GHGEmissionsIntensity']

# %% [markdown]
# On voit que certaines features sont absentes. Il aurait été intéressant d'avoir l'année de construction, le nombre de bâtiments, d'étages par exemple dont on peut supposer qu'elles ont un impact sur la target. Dans une deuxième approche on essaye la méthode Kbest.

# %% [markdown]
# ### Phase modelling: selection features avec KBest, SVR
# - Création "numerical_features" et "categorical_features"
# - Traitements nécessaires sur "numerical_features"
# - Traitements nécessaires sur "categorical_features"
# - Création transformers
# - Choix d'un estimateur
# - Création pipeline
# - Variables X et y
# - Split data, train_set, test_set
# - Transformations, entrainement
# - Score

# %% [markdown]
# #### Création "numerical_features" et "categorical_features"

# %% [markdown]
# ##### Définition des subsets X et y.

# %% [markdown]
# ###### X représente le dataset sur lequel entrainer le modèle, y la target. X comprend différents formats qu'il faut scinder pour pouvoir les transformer séparément. On va donc définir deux sbsets:
# - X_cat, subset contenant les features catégorielles.
# - X_num, subset contenant les features numériques

# %% [markdown]
# ###### Opérations préalables dataset
# - Enlever certaines features non utiles
# - Enlever certaines catégories dont la fréquence d'occurence=1 (erreur dans train_test_split())

# %% [markdown]
# Pour les variables catégorielles, plusieurs d'entre elles n'offrent pas d'intérêt: "City", "State", "TaxParcelIdentificationNumber", "ListOfAllPropertyUseTypes", "'YearsENERGYSTARCertified", "PropertyName", "Address". Soit ces variables ne varient pas (n'ont donc pas d'effet sur la target, soit elles sont corrélées à d'autres variables et traduisent la même information (cas de TaxParcelIdentificationNumber ou Address et Neighborhood). On exclut ces variables.

# %% [markdown]
# Le dataset d'input est df_temp

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   BuildingType                     3376 non-null   object
#  1   PrimaryPropertyType              3376 non-null   object
#  2   PropertyName                     3376 non-null   object
#  3   Address                          3376 non-null   object
#  4   City                             3376 non-null   object
#  5   State                            3376 non-null   object
#  6   TaxParcelIdentificationNumber    3376 non-null   object
#  7   Neighborhood                     3376 non-null   object
#  8   Latitude                         3376 non-null   float64
#  9   Longitude                        3376 non-null   float64
#  10  YearBuilt                        3376 non-null   int64
#  11  NumberofBuildings                3368 non-null   float64
# ...

# %%
# Exclusion des features de type catégoriel n'ayant pas d'interêt.
to_be_excluded_cat = ['City', 'State', 'TaxParcelIdentificationNumber', 'ListOfAllPropertyUseTypes',
                 'YearsENERGYSTARCertified', 'PropertyName', 'Address', 'ComplianceStatus']
condition_1 = (df_temp.columns.isin(to_be_excluded_cat))

df_temp = df_temp.loc[:,condition_1==False]
X_cat = df_temp.select_dtypes(object)

# %%
X_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BuildingType                  3376 non-null   object
#  1   PrimaryPropertyType           3376 non-null   object
#  2   Neighborhood                  3376 non-null   object
#  3   LargestPropertyUseType        3356 non-null   object
#  4   SecondLargestPropertyUseType  1679 non-null   object
#  5   ThirdLargestPropertyUseType   596 non-null    object
# dtypes: object(6)
# memory usage: 158.4+ KB

# %% [markdown]
# Pour plusieurs variables, on a des catégories pour lesquelles on a un seul échantillon. Ceci posera problème lors de l'étape "train_test_split". En effet pour la catégorie pour laquelle on a une seule valeur, on ne pourra pas dispatcher cette catégorie entre "train" et "test". On exclut ces catégories pour ne pas provoquer d'erreur par la suite.
# - On renomme numerical_features en X_num
# - On concatène X_num et X_cat ==> X
# - On exclut les lignes avec occurence=1

# %%
X_num = numerical_features

# %%
X = pd.concat([X_num, X_cat], axis=1)

# %%
#X.head(3)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         3376 non-null   float64
#  1   Longitude                        3376 non-null   float64
#  2   YearBuilt                        3376 non-null   int64
#  3   NumberofBuildings                3376 non-null   float64
#  4   NumberofFloors                   3376 non-null   int64
#  5   PropertyGFAParking               3376 non-null   int64
#  6   PropertyGFABuilding(s)           3376 non-null   int64
#  7   LargestPropertyUseTypeGFA        3376 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  3376 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   3376 non-null   float64
#  10  ENERGYSTARScore                  3376 non-null   float64
#  11  SiteEUI(kBtu/sf)                 3376 non-null   float64
# ...

# %%
# Vérification des valeurs des features X_cat
def check(df):
    l_pos = []
    
    for i in range(len(df.columns)):
        col_name = df.columns[i]
        #print(col_name)
        
        s = df.iloc[:,i]
        #print(s)
        #print(s.dtypes)
        #print(type(s))
        cond = (s.dtypes == object)
        
        if cond:

            f = s.value_counts() # comptage des fréquences d'apparition
        
            v = f[f<=1] # ensemble des valeurs avec fréquence <=1
            #print(v)
            #print(v.index)
        
            for j in range(len(v.index)):
                e = v.index[j] # chaine de caractère correspondant à l'index de la série
                        
                pos_df = df.loc[df[col_name] == e].index # chercher la chaine de caractére dans df et obtenir l'index
                
                pos_df = list(pos_df)
            
                l_pos.append(pos_df)
        
            
    return l_pos

# %%
list_of_list = check(X)

# %%
# Exclusion des lignes portant l'index indiqué dans "list_of_list".
def supp_rows (df, liste):
    pos = [val for sublist in list_of_list for val in sublist]
    df = df.drop(pos, axis=0)
    
    return df

# %%
# Exclusion des lignes avec occurence=1.

X = supp_rows(X, list_of_list)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3345 entries, 0 to 3375
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         3345 non-null   float64
#  1   Longitude                        3345 non-null   float64
#  2   YearBuilt                        3345 non-null   int64
#  3   NumberofBuildings                3345 non-null   float64
#  4   NumberofFloors                   3345 non-null   int64
#  5   PropertyGFAParking               3345 non-null   int64
#  6   PropertyGFABuilding(s)           3345 non-null   int64
#  7   LargestPropertyUseTypeGFA        3345 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  3345 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   3345 non-null   float64
#  10  ENERGYSTARScore                  3345 non-null   float64
#  11  SiteEUI(kBtu/sf)                 3345 non-null   float64
# ...

# %%
# Reset de l'index

X.reset_index(drop=True,inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3345 entries, 0 to 3344
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         3345 non-null   float64
#  1   Longitude                        3345 non-null   float64
#  2   YearBuilt                        3345 non-null   int64
#  3   NumberofBuildings                3345 non-null   float64
#  4   NumberofFloors                   3345 non-null   int64
#  5   PropertyGFAParking               3345 non-null   int64
#  6   PropertyGFABuilding(s)           3345 non-null   int64
#  7   LargestPropertyUseTypeGFA        3345 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  3345 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   3345 non-null   float64
#  10  ENERGYSTARScore                  3345 non-null   float64
#  11  SiteEUI(kBtu/sf)                 3345 non-null   float64
# ...

# %%
X.isnull().mean()*100
# Out:
# Latitude                            0.000000
# Longitude                           0.000000
# YearBuilt                           0.000000
# NumberofBuildings                   0.000000
# NumberofFloors                      0.000000
# PropertyGFAParking                  0.000000
# PropertyGFABuilding(s)              0.000000
# LargestPropertyUseTypeGFA           0.000000
# SecondLargestPropertyUseTypeGFA     0.000000
# ThirdLargestPropertyUseTypeGFA      0.000000
# ENERGYSTARScore                     0.000000
# SiteEUI(kBtu/sf)                    0.000000
# SourceEUI(kBtu/sf)                  0.000000
# SiteEnergyUse(kBtu)                 0.000000
# SteamUse(kBtu)                      0.000000
# Electricity(kBtu)                   0.000000
# NaturalGas(kBtu)                    0.000000
# TotalGHGEmissions                   0.000000
# GHGEmissionsIntensity               0.000000
# BuildingType                        0.000000
# PrimaryPropertyType                 0.000000
# ...

# %%
X.drop('ThirdLargestPropertyUseType', axis=1,inplace=True)

# %%
X.isnull().mean()*100
# Out:
# Latitude                            0.000000
# Longitude                           0.000000
# YearBuilt                           0.000000
# NumberofBuildings                   0.000000
# NumberofFloors                      0.000000
# PropertyGFAParking                  0.000000
# PropertyGFABuilding(s)              0.000000
# LargestPropertyUseTypeGFA           0.000000
# SecondLargestPropertyUseTypeGFA     0.000000
# ThirdLargestPropertyUseTypeGFA      0.000000
# ENERGYSTARScore                     0.000000
# SiteEUI(kBtu/sf)                    0.000000
# SourceEUI(kBtu/sf)                  0.000000
# SiteEnergyUse(kBtu)                 0.000000
# SteamUse(kBtu)                      0.000000
# Electricity(kBtu)                   0.000000
# NaturalGas(kBtu)                    0.000000
# TotalGHGEmissions                   0.000000
# GHGEmissionsIntensity               0.000000
# BuildingType                        0.000000
# PrimaryPropertyType                 0.000000
# ...

# %%
label = 'SiteEUI(kBtu/sf)'

# %%
y = X[label]

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3345 entries, 0 to 3344
# Series name: SiteEUI(kBtu/sf)
# Non-Null Count  Dtype
# --------------  -----
# 3345 non-null   float64
# dtypes: float64(1)
# memory usage: 26.3 KB

# %%
X_wo_Y = X.drop(label, axis=1)

# %%
X_wo_Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3345 entries, 0 to 3344
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         3345 non-null   float64
#  1   Longitude                        3345 non-null   float64
#  2   YearBuilt                        3345 non-null   int64
#  3   NumberofBuildings                3345 non-null   float64
#  4   NumberofFloors                   3345 non-null   int64
#  5   PropertyGFAParking               3345 non-null   int64
#  6   PropertyGFABuilding(s)           3345 non-null   int64
#  7   LargestPropertyUseTypeGFA        3345 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  3345 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   3345 non-null   float64
#  10  ENERGYSTARScore                  3345 non-null   float64
#  11  SourceEUI(kBtu/sf)               3345 non-null   float64
# ...

# %%
y_nan = y.loc[y.isnull() == True]

# %%
y_nan.index
# Out:
# Int64Index([], dtype='int64')

# %%
X_wo_Y.shape
# Out:
# (3345, 23)

# %%
print(y.shape, type(y))
# Out:
# (3345,) <class 'pandas.core.series.Series'>

# %% [markdown]
# #### Définition des features

# %%
# Distinguer les formats "Num" et "Cat" pour X
numerical_features = X_wo_Y.select_dtypes(include=['float64']).columns.tolist()
categorical_features = X_wo_Y.select_dtypes(include="object").columns.tolist()

# %%
numerical_features
# Out:
# ['Latitude',
#  'Longitude',
#  'NumberofBuildings',
#  'LargestPropertyUseTypeGFA',
#  'SecondLargestPropertyUseTypeGFA',
#  'ThirdLargestPropertyUseTypeGFA',
#  'ENERGYSTARScore',
#  'SourceEUI(kBtu/sf)',
#  'SiteEnergyUse(kBtu)',
#  'SteamUse(kBtu)',
#  'Electricity(kBtu)',
#  'NaturalGas(kBtu)',
#  'TotalGHGEmissions',
#  'GHGEmissionsIntensity']

# %% [markdown]
# #### Construction des pipelines "Num" et "Cat"

# %%
# Pipeline numérique features

numerical_pipeline = make_pipeline(SimpleImputer(strategy='median'),
                                   RobustScaler())

# %%
# Pipeline categorical features

categorical_pipeline = make_pipeline(SimpleImputer(strategy='most_frequent'), 
                                     OneHotEncoder(categories='auto', 
                                                   handle_unknown='infrequent_if_exist',
                                                   sparse_output=False))

# %% [markdown]
# #### Définition des transformations

# %%
preprocessor = make_column_transformer((numerical_pipeline, numerical_features),
                                         (categorical_pipeline, categorical_features))

# %% [markdown]
# #### Transformations sur y

# %%
robust_scaler = RobustScaler()

# %%
y_reshaped = y.values.reshape(-1,1)

# %%
y_scaled_T = robust_scaler.fit_transform(y_reshaped)

# %%
y_scaled_T
# Out:
# array([[ 1.33850932],
#        [ 1.74534182],
#        [ 1.78260881],
#        ...,
#        [12.40993876],
#        [ 0.38509323],
#        [ 0.76086959]])

# %%
print(y_scaled_T.shape)
# Out:
# (3345, 1)

# %% [markdown]
# #### Split dataset

# %%
X_train, X_test,y_train ,y_test = train_test_split(X_wo_Y, y_scaled_T, test_size=0.20, random_state=0)

# %% [markdown]
# #### Construction de la pipeline transformations + selection features + estimateur

# %%
selector = SelectKBest(f_regression,k=10)

# %%
estimator = SVR(kernel='rbf')

# %%
pipe = make_pipeline(preprocessor, selector)

# %%
model = make_pipeline(pipe, estimator)

# %%
model.fit(X_train, y_train)
# Out:
# /Users/olivierdebeyssac/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/olivierdebeyssac/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columntransformer',
#                                   ColumnTransformer(transformers=[('pipeline-1',
#                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                     SimpleImputer(strategy='median')),
# ...

# %% [markdown]
# #### Score

# %%
model.score(X_test, y_test)
# Out:
# 0.7899275840774128

# %%
selected_feat = pipe.get_feature_names_out(input_features=X_wo_Y.columns)

# %%
selected_feat
# Out:
# array(['pipeline-1__SourceEUI(kBtu/sf)',
#        'pipeline-1__SiteEnergyUse(kBtu)', 'pipeline-1__Electricity(kBtu)',
#        'pipeline-1__NaturalGas(kBtu)', 'pipeline-1__TotalGHGEmissions',
#        'pipeline-1__GHGEmissionsIntensity',
#        'pipeline-2__PrimaryPropertyType_Supermarket / Grocery Store',
#        'pipeline-2__LargestPropertyUseType_Data Center',
#        'pipeline-2__LargestPropertyUseType_Multifamily Housing',
#        'pipeline-2__LargestPropertyUseType_Supermarket/Grocery Store'],
#       dtype=object)

# %% [markdown]
# ###### Le score obtenu n'est pas encore acceptable. Le modèle n'est pas adéquat pour l'obtention de prédictions fiables, puisque l'on obtiendrait une bonne prédiction dans seulement 79% des cas. On doit donc tester d'autres modèles.

# %% [markdown]
# ## Phase Modelling: Regression polynomiale

# %% [markdown]
# ### Création nouveau preprocessor

# %% [markdown]
# Le modèle de régression polynomial va créer autant de nouvelles variables que de degrés du polynome auxquelles on ajoute autant d'interactions que de nombre de variables initiales. Il en résulte un grand nombre de variables, ce qui peut se traduire par un manque de ressources de calcul. On va donc ici réduire le nombre de variables en prenant la sélection qui est l'output de selectKBest.

# %% [markdown]
# En partant de X (label y déja exclut), on ne garge que les features "selected_feat"

# %%
def filtre(l):
    l_filtered=[]
    for i in range(len(l)):
        element = l[i].split('__')[1]
        element = element.split('_')[0]
        l_filtered.append(element)
    return l_filtered

# %%
l_filtered = filtre(selected_feat)

# %%
l_filtered = np.unique(l_filtered)

# %%
X_filt = X_wo_Y.loc[:,l_filtered]

# %%
X_filt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3345 entries, 0 to 3344
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Electricity(kBtu)       3345 non-null   float64
#  1   GHGEmissionsIntensity   3345 non-null   float64
#  2   LargestPropertyUseType  3325 non-null   object
#  3   NaturalGas(kBtu)        3345 non-null   float64
#  4   PrimaryPropertyType     3345 non-null   object
#  5   SiteEnergyUse(kBtu)     3345 non-null   float64
#  6   SourceEUI(kBtu/sf)      3345 non-null   float64
#  7   TotalGHGEmissions       3345 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 209.2+ KB

# %% [markdown]
# Scinder en X_num et X_cat

# %%
X_num = X_filt.select_dtypes('float64')
numerical_features = X_num.columns.tolist()

X_cat = X_filt.select_dtypes('object')
categorical_features = X_cat.columns.tolist()

# %%
categorical_features
# Out:
# ['LargestPropertyUseType', 'PrimaryPropertyType']

# %%
X_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3345 entries, 0 to 3344
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Electricity(kBtu)      3345 non-null   float64
#  1   GHGEmissionsIntensity  3345 non-null   float64
#  2   NaturalGas(kBtu)       3345 non-null   float64
#  3   SiteEnergyUse(kBtu)    3345 non-null   float64
#  4   SourceEUI(kBtu/sf)     3345 non-null   float64
#  5   TotalGHGEmissions      3345 non-null   float64
# dtypes: float64(6)
# memory usage: 156.9 KB

# %%
X_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3345 entries, 0 to 3344
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   LargestPropertyUseType  3325 non-null   object
#  1   PrimaryPropertyType     3345 non-null   object
# dtypes: object(2)
# memory usage: 52.4+ KB

# %%
# Pipeline numérique features

numerical_pipeline = make_pipeline(SimpleImputer(strategy='median'),
                                   RobustScaler())

# %%
# Pipeline categorical features

categorical_pipeline = make_pipeline(SimpleImputer(strategy='most_frequent'), 
                                     OneHotEncoder(categories='auto', 
                                                   handle_unknown='infrequent_if_exist',
                                                   sparse_output=False))

# %%
categorical_pipeline
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                sparse_output=False))])

# %% [markdown]
# On spécifie qu'on ne veut faire aucune transformation sur features numériques avant d'avoir fait la transformation polynomiale. C'est l'objet de "remainder".

# %%
preprocessor_poly = make_column_transformer((numerical_pipeline, []),(categorical_pipeline, categorical_features), remainder='passthrough')

# %%
preprocessor_poly
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('robustscaler',
#                                                   RobustScaler())]),
#                                  []),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                                                 sparse_output=False))]),
#                                  ['LargestPropertyUseType',
# ...

# %%
# Découpage data set en train et test sets
Xp_train, Xp_test,yp_train ,yp_test = train_test_split(X_filt, y, test_size=0.20, random_state=0)

# %% [markdown]
# ### Optimisation hyper paramètre degré du polynome

# %%
# Définition hyper paramètre à optimiser
params={'polynomialfeatures__degree':[0, 1, 2, 3]}

# %%
# Modèle incluant les étapes de preprocessing, feature engineering, et application du modèle linéaire
poly = make_pipeline(preprocessor_poly, PolynomialFeatures(), RobustScaler(),LinearRegression())

# %%
# Construction grille recherche optimisation hyper paramètre "degré" sur le modèle
search = GridSearchCV(poly, params, cv=4, scoring='neg_mean_absolute_error')

# %%
search.get_params()
# Out:
# {'cv': 4,
#  'error_score': nan,
#  'estimator__memory': None,
#  'estimator__steps': [('columntransformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('pipeline-1',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('robustscaler',
#                                                      RobustScaler())]),
#                                     []),
#                                    ('pipeline-2',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('onehotencoder',
#                                                      OneHotEncoder(handle_unknown='infrequent_if_exist',
# ...

# %%
# Entrainement du modèle grid sur data d'entrainement
search.fit(Xp_train, yp_train)
# Out:
# GridSearchCV(cv=4,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('robustscaler',
#                                                                                           RobustScaler())]),
#                                                                          []),
#                                                                         ('pipeline-2',
#                                                                          Pipeline(steps=[('simpleimputer',
# ...

# %% [markdown]
# ### Output phase optimisation

# %%
search.cv_results_
# Out:
# {'mean_fit_time': array([7.19922781e-03, 2.39601731e-02, 3.07216042e+00, 3.10448540e+01]),
#  'std_fit_time': array([0.0020206 , 0.00591872, 0.34278623, 1.50312704]),
#  'mean_score_time': array([0.00274026, 0.00319809, 0.01980472, 0.41770428]),
#  'std_score_time': array([0.000175  , 0.00063514, 0.00476112, 0.04166496]),
#  'param_polynomialfeatures__degree': masked_array(data=[0, 1, 2, 3],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'polynomialfeatures__degree': 0},
#   {'polynomialfeatures__degree': 1},
#   {'polynomialfeatures__degree': 2},
#   {'polynomialfeatures__degree': 3}],
#  'split0_test_score': array([-3.18319712e+01, -3.03220004e+00, -1.10939676e+09, -6.09875734e+08]),
#  'split1_test_score': array([-3.18630608e+01, -8.00019845e+07, -1.30454778e+08, -4.71767704e+08]),
#  'split2_test_score': array([-3.11346645e+01, -2.90425297e+09, -5.68096687e+07, -1.45468948e+09]),
# ...

# %%
search.best_params_
# Out:
# {'polynomialfeatures__degree': 0}

# %%
search.best_score_
# Out:
# -31.470659285405365

# %% [markdown]
# ### Performance modèle régression polynomiale

# %%
# Modèle incluant les étapes de preprocessing, feature engineering, et application du modèle linéaire
poly = make_pipeline(preprocessor_poly.fit(Xp_train), PolynomialFeatures(degree=0), RobustScaler(),LinearRegression())

# %%
poly.fit(Xp_train, yp_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('robustscaler',
#                                                                    RobustScaler())]),
#                                                   []),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %%
poly.score(Xp_test, yp_test)
# Out:
# -1.0479355982973004e-07

# %% [markdown]
# On peut conclure que le modèle polynomial n'est pas satisfaisant puisque le score est quasiment nul, ce qui traduit une absence de relation entre y et les feature. NB: ici (contexte de limitation de puissance de calcul ==> restriction du périmètre features à celui de selectKBest)

# %% [markdown]
# ## Phase Modelling: Random Forest

# %% [markdown]
# ### Instantiation du modèle, entrainement

# %% [markdown]
# #### Définition modèle et preprocessing

# %%
# Instantiation du modèle avec 1000 arbres de décision.
rf = RandomForestRegressor(n_estimators = 1000, random_state = 0)

# %%
pipe_rf = make_pipeline(preprocessor, rf)

# %% [markdown]
# ### Entrainement

# %%
rf_fitted = pipe_rf.fit(X_train, y_train.ravel())

# %% [markdown]
# ### Score

# %%
rf_fitted.score(X_test, y_test)
# Out:
# 0.9807788431061647

# %%
y_pred = pipe_rf.predict(X_test)
print(y_pred.shape)
# Out:
# (669,)

# %%
d_ = {'actuals':y_test.ravel(), 'pred': y_pred}

df = pd.DataFrame(d_)

# %%
# Visualisation

# df1= non optimisé
# df2 = optimisé

def vis(df):
    fig, axes = plt.subplots(1, 1, figsize=(6, 4))
    
    sns.scatterplot(data=df, x='actuals', y='pred')
    
    plt.xticks(fontsize=7, rotation=45)
    plt.yticks(fontsize=7, rotation=45)
    plt.title('Random Forest - actuals vs. pred - SiteEUI')
    plt.show()
    
    return

# %%
vis(df)

# %% [markdown]
# ### Classement des variables (Feature importance)

# %%
preprocessor.get_feature_names_out()
print(len(preprocessor.get_feature_names_out()))
# Out:
# 139

# %%
pipe_rf.named_steps['randomforestregressor'].feature_importances_
print(pipe_rf.named_steps['randomforestregressor'].feature_importances_.shape)
# Out:
# (139,)

# %%
def importance(names,arr):
    df = pd.DataFrame(data=pipe_rf.named_steps['randomforestregressor'].feature_importances_,
                     index=preprocessor.get_feature_names_out())
    df.reset_index(inplace=True)
    df.rename(columns={0: 'values', 'index':'categories'}, inplace=True)
    df['features']=0
    df['features'].astype(str)
    
    df['features']=df['categories'].apply(lambda x: x.split('__')[1])
    df['features']=df['features'].apply(lambda x: x.split('_')[0])
    
    df = df.groupby(['features','categories'], as_index=False).sum()
    
    df['log_values'] = np.log(df['values'])
    df.sort_values(by=['log_values'], ascending=True,inplace=True)
    
    return df

# %%
df = importance(preprocessor.get_feature_names_out(),pipe_rf.named_steps['randomforestregressor'].feature_importances_)

# %%
df.head()
# Out:
#                          features  \
# 34         LargestPropertyUseType
# 125  SecondLargestPropertyUseType
# 81            PrimaryPropertyType
# 62                   Neighborhood
# 97   SecondLargestPropertyUseType
#
#                                             categories        values  \
# 34   pipeline-2__LargestPropertyUseType_Other - Uti...  1.989600e-09
# 125  pipeline-2__SecondLargestPropertyUseType_Refri...  4.257342e-09
# 81   pipeline-2__PrimaryPropertyType_Low-Rise Multi...  5.845017e-09
# 62                   pipeline-2__Neighborhood_Delridge  1.313165e-08
# 97   pipeline-2__SecondLargestPropertyUseType_Adult...  1.478053e-08
#
#      log_values
# 34   -20.035332
# 125  -19.274621
# 81   -18.957676
# 62   -18.148241
# 97   -18.029955

# %%
def vis_importance(df):

    fig, axes = plt.subplots(1,1, figsize=(12, 5))
    sns.barplot(data=df, x='features',y='log_values')
    plt.xticks(fontsize=6, rotation=45)
    plt.title('Featues importance - Energy cons.')
    plt.show()
    return

# %%
vis_importance(df)

# %% [markdown]
# ## Phase Modelling: Adaboost

# %% [markdown]
# #### Définition modèle et preprocessing

# %%
ada = AdaBoostRegressor(n_estimators = 1000, random_state = 0)

# %%
pipe_ada = make_pipeline(preprocessor, ada)

# %% [markdown]
# ### Entrainement

# %%
ada_fitted = pipe_ada.fit(X_train, y_train)
# Out:
# /Users/olivierdebeyssac/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Score.

# %%
ada_fitted.score(X_test, y_test)
# Out:
# 0.8644090597179399

# %% [markdown]
# ## Première conclusion

# %% [markdown]
# A ce stade de l'analyse, on peut tirer une première conclusion: Le modèle le plus performant dans le contexte dans lequel on se trouve est Random Forest. La technique de "Bagging" (analyse en parallèle) est ici plus performante que la technique concurrente du "Boosting".

# %% [markdown]
# L'objectif ici est de s'intéresser à la consommation et aux émissions des bâtiments non destinés à l’habitation. Or pour le moment le dataset contient aussi bien des bâtimments d'habitation que des bâtiments non destinés à l'habitation. Il faut donc maintenant exlure du dataset les objets non destinés à l'habitation.

# %% [markdown]
# ## Modélisation pour le non résidentiel

# %% [markdown]
# ### Réduction dataset, exclusion des bâtiments destinés à l'habitation.

# %%
condition = (X['BuildingType'].isin(non_residential) == True)
X_nr = X[condition]

# %%
X_nr['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus'], dtype=object)

# %%
X_nr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1642 entries, 0 to 3344
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         1642 non-null   float64
#  1   Longitude                        1642 non-null   float64
#  2   YearBuilt                        1642 non-null   int64
#  3   NumberofBuildings                1642 non-null   float64
#  4   NumberofFloors                   1642 non-null   int64
#  5   PropertyGFAParking               1642 non-null   int64
#  6   PropertyGFABuilding(s)           1642 non-null   int64
#  7   LargestPropertyUseTypeGFA        1642 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  1642 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   1642 non-null   float64
#  10  ENERGYSTARScore                  1642 non-null   float64
#  11  SiteEUI(kBtu/sf)                 1642 non-null   float64
# ...

# %%
X_nr.shape
# Out:
# (1642, 24)

# %%
label = 'SiteEUI(kBtu/sf)'
y = X_nr[label]

# %%
X_nr_wo_y = X_nr.drop(label, axis=1)

# %%
X_nr_wo_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1642 entries, 0 to 3344
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         1642 non-null   float64
#  1   Longitude                        1642 non-null   float64
#  2   YearBuilt                        1642 non-null   int64
#  3   NumberofBuildings                1642 non-null   float64
#  4   NumberofFloors                   1642 non-null   int64
#  5   PropertyGFAParking               1642 non-null   int64
#  6   PropertyGFABuilding(s)           1642 non-null   int64
#  7   LargestPropertyUseTypeGFA        1642 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  1642 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   1642 non-null   float64
#  10  ENERGYSTARScore                  1642 non-null   float64
#  11  SourceEUI(kBtu/sf)               1642 non-null   float64
# ...

# %% [markdown]
# ### Preprocessing

# %%
robust_scaler = RobustScaler()
y_reshaped = y.values.reshape(-1,1)
y_scaled_T = robust_scaler.fit_transform(y_reshaped)

# %%
y_scaled_T.shape
# Out:
# (1642, 1)

# %% [markdown]
# ### Split dataset

# %%
X_nr_train, X_nr_test, y_nr_train, y_nr_test = train_test_split(X_nr_wo_y, y_scaled_T)

# %% [markdown]
# ### Application modèle, Random Forest

# %%
# Instantiation du modèle avec 1000 arbres de décision.
rf = RandomForestRegressor(n_estimators = 1000, random_state = 0)

# %%
pipe_rf = make_pipeline(preprocessor, rf)

# %%
rf_fitted = pipe_rf.fit(X_nr_train, y_nr_train)
# Out:
# /Users/olivierdebeyssac/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py:406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %% [markdown]
# ### Score

# %%
rf_fitted.score(X_nr_test, y_nr_test)
# Out:
# 0.9458361929712915

# %% [markdown]
# ## Importance variable EnergyStarScore, "SiteEUI(kBtu/sf)", non résidentiel.

# %% [markdown]
# Est ce que la variable "ENERGYSTARScore" a une capacité à influer sur le label ? On fait cette vérification en se basant sur Random Forest après exclusion de la variable. Si la performance est différente, on pourra en déduire qu'il y a une influence.

# %% [markdown]
# ### Analyse de l'influence.

# %%
X_nr_wo_y.drop('ENERGYSTARScore', axis=1, inplace=True)

# %%
X_nr_wo_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1642 entries, 0 to 3344
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Latitude                         1642 non-null   float64
#  1   Longitude                        1642 non-null   float64
#  2   YearBuilt                        1642 non-null   int64
#  3   NumberofBuildings                1642 non-null   float64
#  4   NumberofFloors                   1642 non-null   int64
#  5   PropertyGFAParking               1642 non-null   int64
#  6   PropertyGFABuilding(s)           1642 non-null   int64
#  7   LargestPropertyUseTypeGFA        1642 non-null   float64
#  8   SecondLargestPropertyUseTypeGFA  1642 non-null   float64
#  9   ThirdLargestPropertyUseTypeGFA   1642 non-null   float64
#  10  SourceEUI(kBtu/sf)               1642 non-null   float64
#  11  SiteEnergyUse(kBtu)              1642 non-null   float64
# ...

# %%
# Distinguer les formats "Num" et "Cat" pour X
numerical_features = X_nr_wo_y.select_dtypes(include=['float64']).columns.tolist()
categorical_features = X_nr_wo_y.select_dtypes(include="object").columns.tolist()

# %%
# Pipeline numérique features
numerical_pipeline = make_pipeline(SimpleImputer(strategy='median'),
                                   RobustScaler())

# %%
preprocessor = make_column_transformer((numerical_pipeline, numerical_features),
                                         (categorical_pipeline, categorical_features))

# %%
pipe_rf = make_pipeline(preprocessor, rf)

# %%
X_train, X_test,y_train ,y_test = train_test_split(X_nr_wo_y, y_scaled_T, test_size=0.20, random_state=0)

# %%
rf_fitted = pipe_rf.fit(X_train, y_train.ravel())

# %%
rf_fitted.score(X_test, y_test)
# Out:
# 0.9490135568807693

# %%
y_pred = pipe_rf.predict(X_test)
print(y_pred.shape)
# Out:
# (329,)

# %%
d_ = {'actuals':y_test.ravel(), 'pred': y_pred}

df = pd.DataFrame(d_)

# %%
vis(df)

# %% [markdown]
# ### Conclusion.

# %% [markdown]
# Pour ce qui est du label "SiteEUI(kBtu/sf)", sur le data set non résidnetiel, l'influence est quasiment nulle, puisque l'on obtient les scores de 0.945 et 0.949 (avec/sans la variable ENERGYStarScore).
